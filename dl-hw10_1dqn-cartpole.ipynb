# %%
import time
import random
import numpy as np
from random import shuffle

import gym

import tensorflow as tf
tf.enable_eager_execution()

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load GYM environment

# %%
env = gym.make('CartPole-v0')

STATE_LIMITS = env.observation_space
NUM_ACTIONS = env.action_space.n

print('Actions: {}'.format(NUM_ACTIONS))
print('States limits:')
for i in range(STATE_LIMITS.shape[0]):
    print('[{}, {}]'.format(STATE_LIMITS.low[i], STATE_LIMITS.high[i]))
# Out:
# Actions: 2
# States limits:
# [-4.800000190734863, 4.800000190734863]
# [-3.4028234663852886e+38, 3.4028234663852886e+38]
# [-0.41887903213500977, 0.41887903213500977]
# [-3.4028234663852886e+38, 3.4028234663852886e+38]

# %% [markdown]
# ## Settings

# %%
lr = 0.01
gamma = 0.95

NUM_EPISODES = 2000
MAX_STEPS = 100
REWARD_AVERAGE_WINDOW = 20

# %%
(1,) + env.observation_space.shape
# Out:
# (1, 4)

# %% [markdown]
# ## DQN Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(24, activation=tf.nn.relu),
    tf.keras.layers.Dense(24, activation=tf.nn.relu),
    tf.keras.layers.Dense(NUM_ACTIONS, activation=None, use_bias=False),
])

def evalQ(s):
    return model(s[None, ...].astype(np.float32)).numpy()[0]
  
replay_buffer = []

# %% [markdown]
# ## Prepare model for training

# %%
def loss(q1, q2):
  return tf.reduce_sum(tf.square(q1 - q2))
   
    

optimizer = tf.train.GradientDescentOptimizer(learning_rate=lr)
model.compile(loss=loss, optimizer=optimizer)

pathLenList = []
totalRewardList = []
totalRewardAverageList = []

# %% [markdown]
# ## DQN training

# %%
for i in range(NUM_EPISODES):
    
    eps = 1./((i/50) + 10)
    
    s = env.reset()
    
    totalReward = 0
    step = 0
    
    while step < MAX_STEPS:
        step += 1

        Q_s = evalQ(s)
        
        if np.random.rand() < eps:
            a = env.action_space.sample()
        else:
            a = np.argmax(Q_s)

        s1, r, done, _ = env.step(a)

        Q_s1 = evalQ(s1)
        
        Q_target = Q_s
        if done:
            Q_target[a] = r
        else:
            Q_target[a] = r + gamma * np.max(Q_s1)
            
        
        replay_buffer.append((s, Q_target))
        shuffle(replay_buffer)
        batch_pairs = replay_buffer[0:16]
        
        
        train_batch = np.array([pair[0] for pair in batch_pairs])
        target_batch = np.array([pair[1] for pair in batch_pairs])
        
        model.train_on_batch(train_batch.astype(np.float32), target_batch)
        
        
        totalReward += r
        s = s1
        
        if done:
            break
            
    pathLenList.append(step)
    totalRewardList.append(totalReward)

    if i % REWARD_AVERAGE_WINDOW == 0 and i >= REWARD_AVERAGE_WINDOW:
        totalRewardAverage = np.mean(totalRewardList[-REWARD_AVERAGE_WINDOW:])
        totalRewardAverageList.append(totalRewardAverage)
        if i % 100 == 0:
            print('Episode {}: average total reward = {}'.format(i, totalRewardAverage))
# Out:
# Episode 100: average total reward = 25.9
# Episode 200: average total reward = 18.05
# Episode 300: average total reward = 19.6
# Episode 400: average total reward = 18.25
# Episode 500: average total reward = 19.25
# Episode 600: average total reward = 16.7
# Episode 700: average total reward = 14.0
# Episode 800: average total reward = 19.8
# Episode 900: average total reward = 17.6
# Episode 1000: average total reward = 15.55
# Episode 1100: average total reward = 15.8
# Episode 1200: average total reward = 16.55
# Episode 1300: average total reward = 9.4
# Episode 1400: average total reward = 9.45
# Episode 1500: average total reward = 9.3
# Episode 1600: average total reward = 9.25
# Episode 1700: average total reward = 9.75
# Episode 1800: average total reward = 9.3
# Episode 1900: average total reward = 9.75

# %% [markdown]
# ## Plot trajectory length over time

# %%
plt.plot(pathLenList)
plt.grid()

# %% [markdown]
# ## Plot average total reward over time

# %%
plt.plot(totalRewardAverageList)
plt.grid()

# %%
RECORD_VIDEO = True

if RECORD_VIDEO:
  
    # !pip install pyvirtualdisplay > /dev/null 2>&1
    # !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

    from pyvirtualdisplay import Display
    display = Display(visible=0, size=(1400, 900))
    display.start()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0814 10:09:01.654075 140187430868864 abstractdisplay.py:151] xdpyinfo was not found, X start can not be checked! Please install xdpyinfo!

# %% [markdown]
# ## Run simulation

# %%
USE_Q = True

if RECORD_VIDEO:
    from gym.wrappers import Monitor
    env_sim = Monitor(env, './video', force=True)
else:
    env_sim = env
    
s = env_sim.reset()
totalReward = 0

for _ in range(1000):
    env_sim.render()
    if USE_Q:
        a = np.argmax(evalQ(s))
    else:
        a = env_sim.action_space.sample()    
    s, r, done, _ = env_sim.step(a)
    totalReward += r
    if done:
        break
       
    if not RECORD_VIDEO:
        time.sleep(1./30)
        
env_sim.close()

print('Total reward = {}'.format(totalReward))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-c08a39922a73> in <module>()
#       7     env_sim = env
#       8
# ----> 9 s = env_sim.reset()
#      10 totalReward = 0
#      11
#
# /usr/local/lib/python3.6/dist-packages/gym/wrappers/monitor.py in reset(self, **kwargs)
#      37         self._before_reset()
#      38         observation = self.env.reset(**kwargs)
# ---> 39         self._after_reset(observation)
#      40
#      41         return observation
#
# /usr/local/lib/python3.6/dist-packages/gym/wrappers/monitor.py in _after_reset(self, observation)
#     191         self.stats_recorder.after_reset(observation)
#     192
# --> 193         self.reset_video_recorder()
#     194
#     195         # Bump *after* all reset activity has finished
#
# /usr/local/lib/python3.6/dist-packages/gym/wrappers/monitor.py in reset_video_recorder(self)
#     212             enabled=self._video_enabled(),
#     213         )
# --> 214         self.video_recorder.capture_frame()
#     215
#     216     def _close_video_recorder(self):
#
# /usr/local/lib/python3.6/dist-packages/gym/wrappers/monitoring/video_recorder.py in capture_frame(self)
#      99
#     100         render_mode = 'ansi' if self.ansi_mode else 'rgb_array'
# --> 101         frame = self.env.render(mode=render_mode)
#     102
#     103         if frame is None:
#
# /usr/local/lib/python3.6/dist-packages/gym/core.py in render(self, mode, **kwargs)
#     274
#     275     def render(self, mode='human', **kwargs):
# --> 276         return self.env.render(mode, **kwargs)
#     277
#     278     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     186         self.poletrans.set_rotation(-x[2])
#     187
# --> 188         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#     189
#     190     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/classic_control/rendering.py in render(self, return_rgb_array)
#      94             buffer = pyglet.image.get_buffer_manager().get_color_buffer()
#      95             image_data = buffer.get_image_data()
# ---> 96             arr = np.fromstring(image_data.data, dtype=np.uint8, sep='')
#      97             # In https://github.com/openai/gym-http-api/issues/2, we
#      98             # discovered that someone using Xmonad on Arch was having
#
# AttributeError: 'ImageData' object has no attribute 'data'

# %% [markdown]
# ## Show the video

# %%
def show_video():
    import glob
    import io
    import base64
    from IPython.display import HTML
    from IPython import display as ipythondisplay

    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
            loop controls style="height: 400px;">
            <source src="data:video/mp4;base64,{0}" type="video/mp4" />
            </video>'''.format(encoded.decode('ascii'))))
    else: 
        print("Could not find video")
    
show_video()
